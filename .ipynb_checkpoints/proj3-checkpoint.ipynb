# %%
# Isaac G Callison
# 6350-001
# Project 3
# Due 2/11/2020

# %%
# imports
import random
from nltk.corpus import stopwords
from nltk.classify import NaiveBayesClassifier
from nltk import classify
from nltk.metrics import *
import collections


#set(stopwords.words('and'))

# %%
# pull in Sotu from file 
sotu_file = 'sotu.txt'
pres_by_party = 'presidentsbyparty.txt'

repub_list = [] ; dem_list = []

with open(pres_by_party) as prez:
    cl = prez.readline()
    cl = cl.strip()
    if (cl == 'Republican'):
        while cl != 'Democrat':
            cl = prez.readline()
            cl = cl.strip()
            if len(cl) > 1:
                repub_list.append(cl)
    repub_list = repub_list[:-1]
    for line in prez:
        if len(line) > 1:
            line = line.strip()
            dem_list.append(line)
     
#sotu = open(sotu_file,'r')
# shift + tab shows documenation.

# %%
testFile = open("test.txt","w+")
stop_words = set(stopwords.words('english'))
with open(sotu_file) as sf:
    lines = sf.readlines()
    glob = [x.replace('\n',' ') for x in lines]
    glob = [x.strip('*') for x in glob]
    
    for line in glob:
        testFile.write(line)    
testFile.close()

# %%
r_file = open("rFile.txt", 'w+')
d_file = open("dFile.txt", 'w+')
with open("test.txt") as tf:
    new_list = []
    lines = tf.readlines()
    lines = str(lines)
    lines = lines.split('@')
    for r,item in enumerate(lines):
        if item in repub_list:
            r_file.write(lines[r])
            r_file.write('\n')
            r_file.write(lines[r+2])
            r_file.write('\n')
        elif item in dem_list:
            d_file.write(lines[r])
            d_file.write('\n')
            d_file.write(lines[r+2])
            d_file.write('\n')


# Clean Sotu, truncate to republican and dem and normalize data
r_file.close()
d_file.close()

# %%
pass

# %%
r_set = set()
r_dict = {}
with open("rFile.txt") as rf:
    r_lines = rf.readlines()
    for word in r_lines:
        word = word.split()
        for item in word:
            if item not in stop_words:
                item = item.lower()
                r_dict[item] = r_dict.get(item,0)+1 
                r_set.add(item)
    print(len(r_set))
    #print(r_dict)
        
# Implement features - how to differentiate from each other?
# Out:
# 30751

# %%
d_set = set()
d_dict = {}
with open("dFile.txt") as df:
    d_lines = df.readlines()
    for word in d_lines:
        word = word.split()
        for item in word:
            if item not in stop_words:
                item = item.lower()
                d_set.add(item)
                d_dict[item] = d_dict.get(item,0)+1
    print(len(d_set))
    #print(d_dict)
    ct = wordCount("andrew")
    print(ct)
# Implement features - how to differentiate from each other?
# Out:
# 27138
# 10

# %%
# USE stopwords??
#stop_words = set(stopwords.words('and'))

# %%
# Run classifier
def wordCount(word):
    return d_dict[word]

# %%
for k,v in d
#labeled_sotu = ([(r,"republican") for key in r_dict])

# %%
print(labeled_sotu)
# Out:
# [(699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 'republican'), (699, 're ...
